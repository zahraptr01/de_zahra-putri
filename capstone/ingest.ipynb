# %%
# !pip list

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
from IPython.display import display
import numpy as np

# %% [markdown]
# ## Data Ingestion

# %%
df_admin = pd.read_csv('data_source/admin.csv', skiprows=4, names=["admin_id", "username", "name", "email", "password", "created_at", "updated_at", "deleted_at"])
df_challenge_confirmations = pd.read_csv('data_source/challenge_confirmations.csv', skiprows=4, names=["challenge_confirmations_id", "challenge_id", "user_id", "description", "date_upload", "challenge_confirmations_status", "created_at", "updated_at", "deleted_at"])
df_challenge_logs = pd.read_csv('data_source/challenge_logs.csv', skiprows=4,  names=["challenge_logs_id", "challenge_id", "user_id", "challenge_logs_status", "created_at", "updated_at", "deleted_at"])
df_challenges = pd.read_csv('data_source/challenges.csv', skiprows=4, names=["challenge_id", "author", "title", "difficulty", "description", "exp", "coin", "image_url", "date_start", "date_end", "impact_categories", "created_at", "updated_at", "deleted_at"])
df_impact_categories = pd.read_csv('data_source/impact_categories.csv', names=["impact_category_id", "name", "impact_poin", "icon_url", "created_at", "updated_at", "deleted_at"])
df_users = pd.read_csv('data_source/users.csv', skiprows=4, names=["user_id", "username", "password", "name", "email", "address", "gender", "phone", "exp", "coin", "avatar_url", "created_at", "deleted_at"])
df_challenge_impact = pd.read_csv('data_source/challenge_impact.csv', skiprows=4, names=["challenge_id", "impact_category_id", "created_at", "updated_at", "deleted_at"])
df_list = [df_admin, df_challenge_confirmations, df_challenge_logs, df_challenges, df_impact_categories, df_users, df_challenge_impact]

# %% [markdown]
# ### Data Cleaning

# %%
for df in df_list:
    df.info()

# %%
df_challenges = df_challenges.drop(columns="impact_categories")

# %%
df_ft_challenges = df_challenges[["challenge_id", "author"]]
df_ft_admin = df_admin[["admin_id"]]
df_ft_challenge_logs = df_challenge_logs[["challenge_logs_id", "challenge_id", "user_id", "challenge_logs_status"]]
df_ft_challenge_confirmations = df_challenge_confirmations[["challenge_confirmations_id", "challenge_id", "user_id", "challenge_confirmations_status", "date_upload"]]
df_ft_users = df_users[["user_id"]]
df_ft_challenge_impact = df_challenge_impact[["challenge_id", "impact_category_id"]]
df_ft_impact_categories = df_impact_categories[["impact_category_id", "impact_poin", "name"]]
# df_ft_list = [df_ft_admin, df_ft_challenge_confirmations, df_ft_challenge_logs, df_ft_challenges, df_ft_users, df_ft_challenge_impact, df_ft_impact_categories]

# %%
for df in df_ft_list:
    df.head()

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Join Fact Table

# %%
challenge_facts = pd.merge(df_ft_challenge_logs, df_ft_challenge_confirmations, on=["challenge_id", "user_id"], how='left')
challenge_facts = pd.merge(challenge_facts, df_ft_challenges, on="challenge_id", how='left')  
challenge_facts = pd.merge(challenge_facts, df_ft_challenge_impact, on="challenge_id", how='left')
challenge_facts = pd.merge(challenge_facts, df_ft_impact_categories, on="impact_category_id", how='left')    
challenge_facts = challenge_facts.drop(columns=["challenge_logs_id", "challenge_confirmations_id", "impact_category_id"])

# %%
challenge_facts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   challenge_id                    50 non-null     object
#  1   user_id                         50 non-null     object
#  2   challenge_logs_status           50 non-null     object
#  3   challenge_confirmations_status  36 non-null     object
#  4   date_upload                     36 non-null     object
#  5   author                          50 non-null     object
#  6   impact_poin                     50 non-null     object
#  7   name                            50 non-null     object
# dtypes: object(8)
# memory usage: 3.2+ KB

# %%
challenge_facts.nunique()
# Out:
# challenge_id                      15
# user_id                           15
# challenge_logs_status              2
# challenge_confirmations_status     3
# date_upload                       18
# author                             5
# impact_poin                        8
# name                              15
# dtype: int64

# %% [markdown]
# ### Handle Missing Value

# %%
challenge_facts['challenge_confirmations_status'] = challenge_facts.apply(lambda row: 
    'Challenge Tidak Diambil' if row['challenge_logs_status'] == 'Ditolak' 
    else ('Challenge Belum Dilakukan' if row['challenge_logs_status'] == 'Diterima' and pd.isnull(row['challenge_confirmations_status']) else row['challenge_confirmations_status']), 
    axis=1)

challenge_facts['date_upload'] = challenge_facts.apply(lambda row: 
    pd.Timestamp('1945-08-17') if (row['challenge_logs_status'] == 'Ditolak') or (row['challenge_logs_status'] == 'Diterima' and pd.isnull(row['date_upload'])) 
    else row['date_upload'], 
    axis=1)

# %%
challenge_facts
# Out:
#                             challenge_id  \
# 0   5fe8f4f6-43ee-4420-8969-bf1a0e19260c
# 1   5fe8f4f6-43ee-4420-8969-bf1a0e19260c
# 2   ba2621ac-6f99-43cb-ab8a-7db626b7c4e4
# 3   ba2621ac-6f99-43cb-ab8a-7db626b7c4e4
# 4   5086c59a-e2f9-44d0-bcc6-f7fdb58f07a4
# 5   5086c59a-e2f9-44d0-bcc6-f7fdb58f07a4
# 6   aa013dc7-4fb3-4cf1-9cc0-e1a0ad60414d
# 7   aa013dc7-4fb3-4cf1-9cc0-e1a0ad60414d
# 8   5550e03b-15c6-43c9-997c-4086adc8b573
# 9   5550e03b-15c6-43c9-997c-4086adc8b573
# 10  9b21b3e5-46ff-42a1-92cc-4969c078ff83
# 11  9b21b3e5-46ff-42a1-92cc-4969c078ff83
# 12  85dd4189-9d2a-42f9-8b26-b03daa7e5869
# 13  85dd4189-9d2a-42f9-8b26-b03daa7e5869
# 14  4cc8b34f-9e3e-4f05-a73a-035395ff546d
# 15  4cc8b34f-9e3e-4f05-a73a-035395ff546d
# 16  1e0f4c4f-5b54-4421-b8c1-46a2d382f8b2
# 17  1e0f4c4f-5b54-4421-b8c1-46a2d382f8b2
# 18  c0aa381d-4c14-4eba-9811-c6356176ab67
# 19  c0aa381d-4c14-4eba-9811-c6356176ab67
# 20  1f6774a8-a173-4161-ad3e-e58400e007b2
# 21  1f6774a8-a173-4161-ad3e-e58400e007b2
# 22  b0ac9f1c-4e13-4848-977a-02dd540369a7
# 23  b0ac9f1c-4e13-4848-977a-02dd540369a7
# 24  2e80a9cf-5007-4eac-9cc8-9a603d954d6a
# 25  2e80a9cf-5007-4eac-9cc8-9a603d954d6a
# 26  0d1233b8-d6e0-40df-8c6f-2ae1f8f2bfb7
# 27  0d1233b8-d6e0-40df-8c6f-2ae1f8f2bfb7
# 28  ce6bf160-34ba-4685-80d7-10df1bd04fd1
# 29  ce6bf160-34ba-4685-80d7-10df1bd04fd1
# 30  ba2621ac-6f99-43cb-ab8a-7db626b7c4e4
# 31  ba2621ac-6f99-43cb-ab8a-7db626b7c4e4
# 32  5086c59a-e2f9-44d0-bcc6-f7fdb58f07a4
# 33  5086c59a-e2f9-44d0-bcc6-f7fdb58f07a4
# 34  5550e03b-15c6-43c9-997c-4086adc8b573
# 35  5550e03b-15c6-43c9-997c-4086adc8b573
# 36  9b21b3e5-46ff-42a1-92cc-4969c078ff83
# 37  9b21b3e5-46ff-42a1-92cc-4969c078ff83
# 38  85dd4189-9d2a-42f9-8b26-b03daa7e5869
# 39  85dd4189-9d2a-42f9-8b26-b03daa7e5869
# 40  4cc8b34f-9e3e-4f05-a73a-035395ff546d
# 41  4cc8b34f-9e3e-4f05-a73a-035395ff546d
# 42  1e0f4c4f-5b54-4421-b8c1-46a2d382f8b2
# 43  1e0f4c4f-5b54-4421-b8c1-46a2d382f8b2
# 44  c0aa381d-4c14-4eba-9811-c6356176ab67
# 45  c0aa381d-4c14-4eba-9811-c6356176ab67
# 46  1f6774a8-a173-4161-ad3e-e58400e007b2
# 47  1f6774a8-a173-4161-ad3e-e58400e007b2
# 48  0d1233b8-d6e0-40df-8c6f-2ae1f8f2bfb7
# 49  0d1233b8-d6e0-40df-8c6f-2ae1f8f2bfb7
#
#                                  user_id challenge_logs_status  \
# 0   5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 1   5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 2   5b9a23e5-e562-4fae-b11c-787e655a67d7              Diterima
# 3   5b9a23e5-e562-4fae-b11c-787e655a67d7              Diterima
# 4   d4a59d1b-38fa-4736-88d7-00cdc02ef5be              Diterima
# 5   d4a59d1b-38fa-4736-88d7-00cdc02ef5be              Diterima
# 6   6932e20c-3c55-4d95-91c5-ce316cc5843f               Ditolak
# 7   6932e20c-3c55-4d95-91c5-ce316cc5843f               Ditolak
# 8   8f25169f-5084-45c3-a99f-40daf59485d4               Ditolak
# 9   8f25169f-5084-45c3-a99f-40daf59485d4               Ditolak
# 10  b7352ca3-fae1-4f3c-85b9-095de368b706              Diterima
# 11  b7352ca3-fae1-4f3c-85b9-095de368b706              Diterima
# 12  29a1ee6d-05bd-4f11-b42a-a6769fd6a509              Diterima
# 13  29a1ee6d-05bd-4f11-b42a-a6769fd6a509              Diterima
# 14  fbfccf91-f6ea-4b4f-952e-f371e9c69d9c              Diterima
# 15  fbfccf91-f6ea-4b4f-952e-f371e9c69d9c              Diterima
# 16  4fe8e112-e3d7-4468-bfd0-24058790bb6e              Diterima
# 17  4fe8e112-e3d7-4468-bfd0-24058790bb6e              Diterima
# 18  56a85666-b5aa-4b39-8823-99c7f789ac7b              Diterima
# 19  56a85666-b5aa-4b39-8823-99c7f789ac7b              Diterima
# 20  c0045c29-d1fa-4524-85fd-3e9341f99c6a               Ditolak
# 21  c0045c29-d1fa-4524-85fd-3e9341f99c6a               Ditolak
# 22  6220c455-f14e-42d3-a73d-2f4573f4cf52              Diterima
# 23  6220c455-f14e-42d3-a73d-2f4573f4cf52              Diterima
# 24  35e243e9-d0b1-40b7-b216-5bc6cc15e243              Diterima
# 25  35e243e9-d0b1-40b7-b216-5bc6cc15e243              Diterima
# 26  8f14519b-ea61-457b-bf96-90504221de90              Diterima
# 27  8f14519b-ea61-457b-bf96-90504221de90              Diterima
# 28  3fb1eb90-805f-4727-9f7d-a6fefc6115f9              Diterima
# 29  3fb1eb90-805f-4727-9f7d-a6fefc6115f9              Diterima
# 30  5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 31  5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 32  5b9a23e5-e562-4fae-b11c-787e655a67d7              Diterima
# 33  5b9a23e5-e562-4fae-b11c-787e655a67d7              Diterima
# 34  6932e20c-3c55-4d95-91c5-ce316cc5843f               Ditolak
# 35  6932e20c-3c55-4d95-91c5-ce316cc5843f               Ditolak
# 36  8f25169f-5084-45c3-a99f-40daf59485d4              Diterima
# 37  8f25169f-5084-45c3-a99f-40daf59485d4              Diterima
# 38  5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 39  5dcdb121-85df-487c-8d4a-b4fd5033c9c0              Diterima
# 40  b7352ca3-fae1-4f3c-85b9-095de368b706              Diterima
# 41  b7352ca3-fae1-4f3c-85b9-095de368b706              Diterima
# 42  d4a59d1b-38fa-4736-88d7-00cdc02ef5be              Diterima
# 43  d4a59d1b-38fa-4736-88d7-00cdc02ef5be              Diterima
# 44  35e243e9-d0b1-40b7-b216-5bc6cc15e243               Ditolak
# 45  35e243e9-d0b1-40b7-b216-5bc6cc15e243               Ditolak
# 46  fbfccf91-f6ea-4b4f-952e-f371e9c69d9c              Diterima
# 47  fbfccf91-f6ea-4b4f-952e-f371e9c69d9c              Diterima
# 48  4fe8e112-e3d7-4468-bfd0-24058790bb6e              Diterima
# 49  4fe8e112-e3d7-4468-bfd0-24058790bb6e              Diterima
#
#    challenge_confirmations_status          date_upload  \
# 0                       Disetujui   2024-06-15 3:21:00
# 1                       Disetujui   2024-06-15 3:21:00
# 2                       Disetujui  2024-07-05 12:30:33
# 3                       Disetujui  2024-07-05 12:30:33
# 4                       Disetujui   2024-08-17 5:21:40
# 5                       Disetujui   2024-08-17 5:21:40
# 6         Challenge Tidak Diambil  1945-08-17 00:00:00
# 7         Challenge Tidak Diambil  1945-08-17 00:00:00
# 8         Challenge Tidak Diambil  1945-08-17 00:00:00
# 9         Challenge Tidak Diambil  1945-08-17 00:00:00
# 10                      Disetujui   2024-11-15 6:55:10
# 11                      Disetujui   2024-11-15 6:55:10
# 12                      Disetujui   2024-12-03 7:07:56
# 13                      Disetujui   2024-12-03 7:07:56
# 14                      Disetujui  2024-12-25 10:00:00
# 15                      Disetujui  2024-12-25 10:00:00
# 16                      Disetujui   2025-01-08 9:00:00
# 17                      Disetujui   2025-01-08 9:00:00
# 18                      Disetujui   2025-02-13 8:00:00
# 19                      Disetujui   2025-02-13 8:00:00
# 20        Challenge Tidak Diambil  1945-08-17 00:00:00
# 21        Challenge Tidak Diambil  1945-08-17 00:00:00
# 22                      Disetujui  2025-03-29 21:44:00
# 23                      Disetujui  2025-03-29 21:44:00
# 24                       Menunggu  2025-04-29 23:59:59
# 25                       Menunggu  2025-04-29 23:59:59
# 26                       Menunggu   2025-05-05 9:00:00
# 27                       Menunggu   2025-05-05 9:00:00
# 28                      Disetujui   2025-06-06 3:00:00
# 29                      Disetujui   2025-06-06 3:00:00
# 30                        Ditolak   2024-07-07 5:41:00
# 31                        Ditolak   2024-07-07 5:41:00
# 32                        Ditolak   2024-08-16 5:20:00
# 33                        Ditolak   2024-08-16 5:20:00
# 34        Challenge Tidak Diambil  1945-08-17 00:00:00
# 35        Challenge Tidak Diambil  1945-08-17 00:00:00
# 36                        Ditolak  2024-11-11 11:11:11
# 37                        Ditolak  2024-11-11 11:11:11
# 38                      Disetujui  2024-12-03 13:03:30
# 39                      Disetujui  2024-12-03 13:03:30
# 40                      Disetujui   2024-12-26 8:00:00
# 41                      Disetujui   2024-12-26 8:00:00
# 42                        Ditolak   2025-01-10 5:00:00
# 43                        Ditolak   2025-01-10 5:00:00
# 44        Challenge Tidak Diambil  1945-08-17 00:00:00
# 45        Challenge Tidak Diambil  1945-08-17 00:00:00
# 46      Challenge Belum Dilakukan  1945-08-17 00:00:00
# 47      Challenge Belum Dilakukan  1945-08-17 00:00:00
# 48      Challenge Belum Dilakukan  1945-08-17 00:00:00
# 49      Challenge Belum Dilakukan  1945-08-17 00:00:00
#
#                                   author impact_poin                     name
# 0   b1e7fdc4-6465-4f06-8914-85b36255368e          50            Berkelanjutan
# 1   b1e7fdc4-6465-4f06-8914-85b36255368e          35            Dapat Terurai
# 2   cf98c726-fb72-4687-9c88-e8ce671c32d6          70             Tanpa Limbah
# 3   cf98c726-fb72-4687-9c88-e8ce671c32d6          30       Dapat Didaur Ulang
# 4   06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          40         Ramah Lingkungan
# 5   06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          30       Dapat Didaur Ulang
# 6   6a53c2db-2fa5-47df-8462-baea4308d48f          60            Rendah Karbon
# 7   6a53c2db-2fa5-47df-8462-baea4308d48f          55           Efisien Energi
# 8   90aae29b-bf80-44bd-ab59-e7388e84e27f          55           Efisien Energi
# 9   90aae29b-bf80-44bd-ab59-e7388e84e27f          50                Hemat Air
# 10  b1e7fdc4-6465-4f06-8914-85b36255368e          50            Tidak Beracun
# 11  b1e7fdc4-6465-4f06-8914-85b36255368e          35               Daur Ulang
# 12  cf98c726-fb72-4687-9c88-e8ce671c32d6          60            Rendah Karbon
# 13  cf98c726-fb72-4687-9c88-e8ce671c32d6          45               Terbarukan
# 14  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          40                  Organik
# 15  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          50                Hemat Air
# 16  6a53c2db-2fa5-47df-8462-baea4308d48f          35               Daur Ulang
# 17  6a53c2db-2fa5-47df-8462-baea4308d48f          60  Dapat Digunakan Kembali
# 18  90aae29b-bf80-44bd-ab59-e7388e84e27f          40         Ramah Lingkungan
# 19  90aae29b-bf80-44bd-ab59-e7388e84e27f          50  Sistem Perdagangan Adil
# 20  b1e7fdc4-6465-4f06-8914-85b36255368e          50                Hemat Air
# 21  b1e7fdc4-6465-4f06-8914-85b36255368e          50            Berkelanjutan
# 22  cf98c726-fb72-4687-9c88-e8ce671c32d6          55           Efisien Energi
# 23  cf98c726-fb72-4687-9c88-e8ce671c32d6          50            Berkelanjutan
# 24  b1e7fdc4-6465-4f06-8914-85b36255368e          40                  Organik
# 25  b1e7fdc4-6465-4f06-8914-85b36255368e          70             Tanpa Limbah
# 26  cf98c726-fb72-4687-9c88-e8ce671c32d6          45        Dapat Dikomposkan
# 27  cf98c726-fb72-4687-9c88-e8ce671c32d6          30       Dapat Didaur Ulang
# 28  b1e7fdc4-6465-4f06-8914-85b36255368e          60            Rendah Karbon
# 29  b1e7fdc4-6465-4f06-8914-85b36255368e          45               Terbarukan
# 30  cf98c726-fb72-4687-9c88-e8ce671c32d6          70             Tanpa Limbah
# 31  cf98c726-fb72-4687-9c88-e8ce671c32d6          30       Dapat Didaur Ulang
# 32  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          40         Ramah Lingkungan
# 33  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          30       Dapat Didaur Ulang
# 34  90aae29b-bf80-44bd-ab59-e7388e84e27f          55           Efisien Energi
# 35  90aae29b-bf80-44bd-ab59-e7388e84e27f          50                Hemat Air
# 36  b1e7fdc4-6465-4f06-8914-85b36255368e          50            Tidak Beracun
# 37  b1e7fdc4-6465-4f06-8914-85b36255368e          35               Daur Ulang
# 38  cf98c726-fb72-4687-9c88-e8ce671c32d6          60            Rendah Karbon
# 39  cf98c726-fb72-4687-9c88-e8ce671c32d6          45               Terbarukan
# 40  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          40                  Organik
# 41  06db6d61-e7c8-4126-ab0f-f2b6bc1458d1          50                Hemat Air
# 42  6a53c2db-2fa5-47df-8462-baea4308d48f          35               Daur Ulang
# 43  6a53c2db-2fa5-47df-8462-baea4308d48f          60  Dapat Digunakan Kembali
# 44  90aae29b-bf80-44bd-ab59-e7388e84e27f          40         Ramah Lingkungan
# 45  90aae29b-bf80-44bd-ab59-e7388e84e27f          50  Sistem Perdagangan Adil
# 46  b1e7fdc4-6465-4f06-8914-85b36255368e          50                Hemat Air
# 47  b1e7fdc4-6465-4f06-8914-85b36255368e          50            Berkelanjutan
# 48  cf98c726-fb72-4687-9c88-e8ce671c32d6          45        Dapat Dikomposkan
# 49  cf98c726-fb72-4687-9c88-e8ce671c32d6          30       Dapat Didaur Ulang

# %% [markdown]
# ## Data Load

# %%
# Read .env
from dotenv import load_dotenv
import os

# Upload to firebase
import firebase_admin
from firebase_admin import credentials
from firebase_admin import storage

# %%
def load_data(df):

    load_dotenv()
    CERTIFICATE_PATH = os.getenv('CERTIFICATE_PATH')
    GOOGLE_STORAGE_BUCKET = os.getenv('GOOGLE_STORAGE_BUCKET')

    try:
        cred = credentials.Certificate(CERTIFICATE_PATH)

        storage_bucket = GOOGLE_STORAGE_BUCKET

        firebase_admin.initialize_app(cred, {"storageBucket": storage_bucket})

        bucket = storage.bucket()

        filename = "challenge_fact_table.csv"

        df.to_csv(filename)

        blob = bucket.blob(blob_name=filename)

        blob.upload_from_filename(filename)

        print("Data loaded successfully")
            
    except Exception as e:
        print(f"An error occurred when loading data to the storage: {e}")

load_data(challenge_facts)
# Out:
# Data loaded successfully

# %%
df_logs = pd.read_csv('data_source/logs.csv')

# %%
df_logs.head()
df_logs.nunique()
# Out:
# insertId                              500
# labels."commit-sha"                     3
# labels."gcb-build-id"                   3
# labels."gcb-trigger-id"                 3
# labels."gcb-trigger-region"             1
# labels.instanceId                       3
# labels."managed-by"                     1
# logName                                 2
# receiveLocation                         0
# receiveTimestamp                      149
# resource.labels.configuration_name      3
# resource.labels.location                2
# resource.labels.project_id              1
# resource.labels.revision_name           3
# resource.labels.service_name            3
# resource.type                           1
# textPayload                           368
# timestamp                             500
# dtype: int64

# %%
with pd.option_context('display.max_rows', None):
    df_logs[["textPayload"]].head()
